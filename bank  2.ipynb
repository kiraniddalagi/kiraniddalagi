# %% [markdown]
# # Banking Assignment — Object-Oriented Programming (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice classes, objects, instance/class attributes, methods, encapsulation, inheritance, polymorphism, composition, abstract classes, dataclasses, properties, protocols, and design patterns. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Create a account class for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    bank_name = 'City Bank'
    def __init__(self, account_ref='ACC-1001', balance=5001):
        self.account_ref = account_ref
        self._balance = float(balance)
    @property
    def balance(self):
        return self._balance
    def deposit(self, amount=1000):
        return self.balance*amount
    def __str__(self):
        return f'{self.account_ref} @ {self.balance:.2f}'
account = Account()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5001.00 5001000.0

# %% [markdown]
# ### Q2. Add an initializer to accountholder for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class AddInitializerToAccountholder:
    bank_name = 'City Bank'
    def __init__(self, account_ref='ACC-1001', balance=5002):
        self.account_ref = account_ref
        self._balance = float(balance)
    @property
    def balance(self):
        return self._balance
    def deposit(self, amount=1000):
        return self.balance*amount
    def __str__(self):
        return f'{self.account_ref} @ {self.balance:.2f}'
account = AddInitializerToAccountholder()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5002.00 5002000.0

# %% [markdown]
# ### Q3. Represent an transfer object for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class RepresentAnTransferObject:
    bank_name = 'City Bank'
    def __init__(self, account_ref='ACC-1001', balance=5003):
        self.account_ref = account_ref
        self._balance = float(balance)
    @property
    def balance(self):
        return self._balance
    def deposit(self, amount=1000):
        return self.balance*amount
    def __str__(self):
        return f'{self.account_ref} @ {self.balance:.2f}'
account = RepresentAnTransferObject()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5003.00 5003000.0

# %% [markdown]
# ### Q4. Add a method that calculates line total for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class AddAMethodThatCalculatesLineTotal:
    bank_name = 'City Bank'
    def __init__(self, account_ref='ACC-1001', balance=5004):
        self.account_ref = account_ref
        self._balance = float(balance)
    @property
    def balance(self):
        return self._balance
    def deposit(self, amount=1000):
        return self.balance*amount
    def __str__(self):
        return f'{self.account_ref} @ {self.balance:.2f}'
account = AddAMethodThatCalculatesLineTotal()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5004.00 5004000.0

# %% [markdown]
# ### Q5. Use a class attribute for branch name for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class UseAClassAttributeForBranchName:
   bank_name = 'City Bank'
   def __init__(self, account_ref='ACC-1001', balance=5005):
       self.account_ref = account_ref
       self._balance = float(balance)
   @property
   def balance(self):
       return self._balance
   def deposit(self, amount=1000):
      return self.balance*amount
   def __str__(self):
       return f'{self.account_ref} @ {self.balance:.2f}'
account = UseAClassAttributeForBranchName()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5005.00 5005000.0

# %% [markdown]
# ### Q6. Write a readable __str__ method for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class WriteAReadableStrMethod:
   bank_name = 'City Bank'
   def __init__(self, account_ref='ACC-1001', balance=5006):
       self.account_ref = account_ref
       self._balance = float(balance)
   @property
   def balance(self):
       return self._balance
   def deposit(self, amount=1000):
       return self.balance*amount
   def __str__(self):
       return f'{self.account_ref} @ {self.balance:.2f}'
account = WriteAReadableStrMethod()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5006.00 5006000.0

# %% [markdown]
# ### Q7. Compare two account references with __eq__ for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CompareTwoAccountReferencesWithEq:
   bank_name = 'City Bank'
   def __init__(self, account_ref='ACC-1001', balance=5007):
       self.account_ref = account_ref
       self._balance = float(balance)
   @property
   def balance(self):
        return self._balance
   def deposit(self, amount=1000):
        return self.balance*amount
   def __str__(self):
        return f'{self.account_ref} @ {self.balance:.2f}'
account = CompareTwoAccountReferencesWithEq()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5007.00 5007000.0

# %% [markdown]
# ### Q8. Protect a amount with a property for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ProtectAAmountWithAProperty:
   bank_name = 'City Bank'
   def __init__(self, account_ref='ACC-1001', balance=5008):
       self.account_ref = account_ref
       self._balance = float(balance)
   @property
   def balance(self):
       return self._balance
   def deposit(self, amount=1000):
       return self.balance*amount
   def __str__(self):
       return f'{self.account_ref} @ {self.balance:.2f}'
account = ProtectAAmountWithAProperty()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5008.00 5008000.0

# %% [markdown]
# ### Q9. Create portfolio and add_item for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CreatePortfolioAndAddItem:
   bank_name = 'City Bank'
   def __init__(self, account_ref='ACC-1001', balance=5009):
       self.account_ref = account_ref
       self._balance = float(balance)
   @property
   def balance(self):
       return self._balance
   def deposit(self, amount=1000):
       return self.balance*amount
   def __str__(self):
       return f'{self.account_ref} @ {self.balance:.2f}'
account = CreatePortfolioAndAddItem()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5009.00 5009000.0

# %% [markdown]
# ### Q10. Model a branchaddress for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ModelABranchaddress:
   bank_name = 'City Bank'
   def __init__(self, account_ref='ACC-1001', balance=5010):
       self.account_ref = account_ref
       self._balance = float(balance)
   @property
   def balance(self):
       return self._balance
   def deposit(self, amount=1000):
       return self.balance*amount
   def __str__(self):
       return f'{self.account_ref} @ {self.balance:.2f}'
account = ModelABranchaddress()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5010.00 5010000.0

# %% [markdown]
# ### Q11. Use a static method to validate account reference for banking case 1; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class UseAStaticMethodToValidateAccountReference:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5011):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = UseAStaticMethodToValidateAccountReference()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5011.00 5011000.0

# %% [markdown]
# ### Q12. Use a class method as an alternate constructor for banking case 1; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class UseAClassMethodAsAnAlternateConstructor:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5012):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = UseAClassMethodAsAnAlternateConstructor()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5012.00 5012000.0

# %% [markdown]
# ### Q13. Track object count for banking case 1; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class TrackObjectCountForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5013):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = TrackObjectCountForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5013.00 5013000.0

# %% [markdown]
# ### Q14. Model a loyaltyaccount for banking case 1; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ModelALoyaltyaccountForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5014):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ModelALoyaltyaccountForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5014.00 5014000.0

# %% [markdown]
# ### Q15. Create a supplier class for banking case 1; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CreateASupplierClassForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5015):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = CreateASupplierClassForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5015.00 5015000.0

# %% [markdown]
# ### Q16. Create a account class for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CreateAAccountClassForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5016):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = CreateAAccountClassForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5016.00 5016000.0

# %% [markdown]
# ### Q17. Add an initializer to accountholder for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class AddAnInitializerToAccountholder:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5017):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = AddAnInitializerToAccountholder()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5017.00 5017000.0

# %% [markdown]
# ### Q18. Represent an transfer object for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class RepresentAnTransferObject:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5018):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = RepresentAnTransferObject()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5018.00 5018000.0

# %% [markdown]
# ### Q19. Add a method that calculates line total for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class AddAMethodThatCalculatesLineTotal:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5019):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = AddAMethodThatCalculatesLineTotal()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5019.00 5019000.0

# %% [markdown]
# ### Q20. Use a class attribute for branch name for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class UseAClassAttributeForBranchName:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5020):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = UseAClassAttributeForBranchName()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5020.00 5020000.0

# %% [markdown]
# ### Q21. Write a readable __str__ method for banking case 2; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class WriteAReadableStrMethod:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5021):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = WriteAReadableStrMethod()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5021.00 5021000.0

# %% [markdown]
# ### Q22. Compare two account references with __eq__ for banking case 2; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CompareTwoAccountReferencesWithEq:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5022):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = CompareTwoAccountReferencesWithEq()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5022.00 5022000.0

# %% [markdown]
# ### Q23. Protect a amount with a property for banking case 2; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ProtectAAmountWithAProperty:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5023):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ProtectAAmountWithAProperty()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5023.00 5023000.0

# %% [markdown]
# ### Q24. Create portfolio and add_item for banking case 2; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CreatePortfolioAndAddItem:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5024):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = CreatePortfolioAndAddItem()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5024.00 5024000.0

# %% [markdown]
# ### Q25. Model a branchaddress for banking case 2; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ModelABranchaddressForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5025):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ModelABranchaddressForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5025.00 5025000.0

# %% [markdown]
# ### Q26. Use a static method to validate account reference for banking case 2; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class UseAStaticMethodToValidateAccountReference:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5026):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = UseAStaticMethodToValidateAccountReference()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5026.00 5026000.0

# %% [markdown]
# ### Q27. Use a class method as an alternate constructor for banking case 2; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class UseAClassMethodAsAnAlternateConstructor:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5027):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
   return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = UseAClassMethodAsAnAlternateConstructor()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5027.00 5027000.0

# %% [markdown]
# ### Q28. Track object count for banking case 2; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class TrackObjectCountForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5028):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = TrackObjectCountForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5028.00 5028000.0

# %% [markdown]
# ### Q29. Model a loyaltyaccount for banking case 2; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ModelALoyaltyaccountForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5029):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ModelALoyaltyaccountForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5029.00 5029000.0

# %% [markdown]
# ### Q30. Create a supplier class for banking case 2; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CreateASupplierClassForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5030):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = CreateASupplierClassForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5030.00 5030000.0

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Inherit perishableaccount from account for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.10
class perishableaccount(Account):
    def balance(self):
      return 0.25
for item in [Account(), perishableaccount()]:
  print(item.balance())
# Out:
# 0.1
# 0.25

# %% [markdown]
# ### Q32. Override a discount method for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.10
class perishableaccount(Account):
    def balance(self):
      return 0.25
for item in [Account(), perishableaccount()]:
  print(item.balance())
# Out:
# 0.1
# 0.25

# %% [markdown]
# ### Q33. Use polymorphic payment processors for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self, account_ref, amount): ...
class Card(Payment):
    def pay(self, account_ref, amount):
        return f'Card charged {amount:.2f} for {account_ref}'
class UPI(Payment):
    def pay(self, account_ref, amount):
        return f'UPI charged {amount:.2f} for {account_ref}'
print(Card().pay('ACC-1033', 250))
print(UPI().pay('ACC-1033', 500))
# Out:
# Card charged 250.00 for ACC-1033
# UPI charged 500.00 for ACC-1033

# %% [markdown]
# ### Q34. Compose transfer from transferline objects for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Transferline:
    def __init__(self, amount, account_ref):
        self.amount = amount
        self.account_ref = account_ref
    def total(self):
        return self.amount
class Transfer:
    def __init__(self, *transferlines):
        self.transferlines = transferlines
    def total(self):
        return sum(t.total() for t in self.transferlines)
print(Transfer(Transferline(100, 'ACC-1034'), Transferline(200, 'ACC-1034')).total())
# Out:
# 300

# %% [markdown]
# ### Q35. Define an abstract paymentmethod for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from abc import ABC,abstractclassmethod
class PaymentMethod(ABC):
    @abstractclassmethod
    def pay(self,account_ref,amount):
        pass
class Card(PaymentMethod):
    def pay(self,account_ref,amount):
        return f'Card charged {amount:.2f} for {account_ref}'
class UPI(PaymentMethod):
    def pay(self,account_ref,amount):
        return f'UPI charged {amount:.2f} for {account_ref}'
print(Card().pay('ACC-1035',250))
# Out:
# Card charged 250.00 for ACC-1035

# %% [markdown]
# ### Q36. Use a dataclass for inventoryrecord for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from dataclasses import dataclass
@dataclass
class InventoryRecord:
    account_ref: str
    item: str
    quantity: int
record = InventoryRecord('ACC-1036', 'Laptop', 10)
print(record)
# Out:
# InventoryRecord(account_ref='ACC-1036', item='Laptop', quantity=10)

# %% [markdown]
# ### Q37. Implement a custom iterator for portfolio for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Portfolio:
    bank_name = 'City Bank'
    def __init__(self, account_ref='ACC-1001', balance=5037):
        self.account_ref = account_ref
        self._balance = float(balance)
    @property
    def balance(self):
        return self._balance
    def deposit(self, amount=1000):
        self._balance += amount
        return self.balance
    def __str__(self):
        return f'{self.account_ref} @ {self.balance:.2f}'
account = Portfolio()
print(account, account.deposit())
# Out:
# ACC-1001 @ 6037.00 6037.0

# %% [markdown]
# ### Q38. Use multiple inheritance carefully for timestampeditem for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.10
class TimestampedItem(Account):
    def balance(self):
      return 0.25
for item in [Account(), TimestampedItem()]:
  print(item.balance())
# Out:
# 0.1
# 0.25

# %% [markdown]
# ### Q39. Create a account factory for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CreateAccountFactory:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5039):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = CreateAccountFactory()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5039.00 5039000.0

# %% [markdown]
# ### Q40. Apply a strategy for interest offers for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ApplyAStrategyForInterestOffers:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5040):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ApplyAStrategyForInterestOffers()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5040.00 5040000.0

# %% [markdown]
# ### Q41. Encapsulate balance reservation for banking case 1; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class EncapsulateBalanceReservation:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5041):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = EncapsulateBalanceReservation()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5041.00 5041000.0

# %% [markdown]
# ### Q42. Model aggregation between branch and employees for banking case 1; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ModelAggregationBetweenBranchAndEmployees:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5042):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ModelAggregationBetweenBranchAndEmployees()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5042.00 5042000.0

# %% [markdown]
# ### Q43. Serialize an transfer to a dictionary for banking case 1; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class SerializeAnTransferToADictionary:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5043):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = SerializeAnTransferToADictionary()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5043.00 5043000.0

# %% [markdown]
# ### Q44. Implement a repository abstraction for banking case 1; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ImplementARepositoryAbstraction:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5044):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ImplementARepositoryAbstraction()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5044.00 5044000.0

# %% [markdown]
# ### Q45. Apply dependency injection to checkout for banking case 1; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from abc import ABC, abstractmethod
class Checkout(ABC):
    @abstractmethod
    def pay(self,account_ref,amount):
        pass
class Card(Checkout):
    def pay(self,account_ref,amount):
        return f'Card charged {amount:.2f} for {account_ref}'
class UPI(Checkout):
    def pay(self,account_ref,amount):
        return f'UPI charged {amount:.2f} for {account_ref}'
print(Card().pay('ACC-1045',250))
# Out:
# Card charged 250.00 for ACC-1045

# %% [markdown]
# ### Q46. Inherit perishableaccount from account for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class InheritPerishableAccountFromAccount:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5046):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = InheritPerishableAccountFromAccount()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5046.00 5046000.0

# %% [markdown]
# ### Q47. Override a discount method for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def balance(self):
       return 0.10
class perishableaccount(Account):
    def balance(self):
      return 0.25
for item in [Account(), perishableaccount()]:
  print(item.balance())
# Out:
# 0.1
# 0.25

# %% [markdown]
# ### Q48. Use polymorphic payment processors for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from abc import ABC, abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self, account_ref, amount): ...
class Card(Payment):
    def pay(self, account_ref, amount):
        return f'Card charged {amount:.2f} for {account_ref}'
print(Card().pay('ACC-1048', 250))
# Out:
# Card charged 250.00 for ACC-1048

# %% [markdown]
# ### Q49. Compose transfer from transferline objects for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Transferline:
    def __init__(self, amount, account_ref):
        self.amount = amount
        self.account_ref = account_ref
    def total(self):
        return self.amount
class Transfer:
  def __init__(self, *transferlines):
    self.transferlines = transferlines
  def total(self):
    return sum(t.total() for t in self.transferlines)
print(Transfer(Transferline(100, 'ACC-1049'), Transferline(200, 'ACC-1049')).total())
# Out:
# 300

# %% [markdown]
# ### Q50. Define an abstract paymentmethod for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod
class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, account_ref, amount): ...
class Card(PaymentMethod):
    def pay(self, account_ref, amount):
        return f'Card charged {amount:.2f} for {account_ref}'
print(Card().pay('ACC-1050', 250))
# Out:
# Card charged 250.00 for ACC-1050

# %% [markdown]
# ### Q51. Use a dataclass for inventoryrecord for banking case 2; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from dataclasses import dataclass
@dataclass
class InventoryRecord:
    account_ref: str
    item: str
    quantity: int
record = InventoryRecord('ACC-1051', 'Laptop', 10)
print(record)
# Out:
# InventoryRecord(account_ref='ACC-1051', item='Laptop', quantity=10)

# %% [markdown]
# ### Q52. Implement a custom iterator for portfolio for banking case 2; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ImplementACustomIteratorForPortfolio:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5052):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ImplementACustomIteratorForPortfolio()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5052.00 5052000.0

# %% [markdown]
# ### Q53. Use multiple inheritance carefully for timestampeditem for banking case 2; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.10
class TimestampedItem(Account):
    def balance(self):
      return 0.25
for item in [Account(), TimestampedItem()]:
  print(item.balance())
# Out:
# 0.1
# 0.25

# %% [markdown]
# ### Q54. Create a account factory for banking case 2; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CreateAAccountFactoryForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5054):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = CreateAAccountFactoryForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5054.00 5054000.0

# %% [markdown]
# ### Q55. Apply a strategy for interest offers for banking case 2; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ApplyAStrategyForInterestOffers:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5055):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ApplyAStrategyForInterestOffers()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5055.00 5055000.0

# %% [markdown]
# ### Q56. Encapsulate balance reservation for banking case 2; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class EncapsulateBalanceReservation:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5056):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = EncapsulateBalanceReservation()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5056.00 5056000.0

# %% [markdown]
# ### Q57. Model aggregation between branch and employees for banking case 2; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class OrderLine:
    def __init__(self,account_ref, item, quantity):
        self.account_ref = account_ref
        self.item = item
        self.quantity = quantity
    def total(self):
        return self.quantity
for item in [OrderLine('ACC-1057', 'Laptop', 10)]:
  print(item.total())
# Out:
# 10

# %% [markdown]
# ### Q58. Serialize an transfer to a dictionary for banking case 2; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class SerializeAnTransferToADictionary:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1058', balance=5058):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def line_total(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = SerializeAnTransferToADictionary()
print(account, account.line_total())
# Out:
# ACC-1058 @ 5058.00 5058000.0

# %% [markdown]
# ### Q59. Implement a repository abstraction for banking case 2; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from abc import ABC,abstractclassmethod
class account(ABC):
  @abstractclassmethod
  def deposit(self,amount):
    pass
class balance(account):
  def deposit(self,amount):
    return amount
print(balance().deposit(250))
# Out:
# 250

# %% [markdown]
# ### Q60. Apply dependency injection to checkout for banking case 2; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ApplyDependencyInjectionToCheckout:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1060', balance=5060):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=100):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ApplyDependencyInjectionToCheckout()
print(account, account.deposit())
# Out:
# ACC-1060 @ 5060.00 506000.0

# %% [markdown]
# ### Q61. Inherit perishableaccount from account for banking case 3; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.01
class perishableaccount(Account):
    def balance(self):
      return 0.12
for item in [Account(), perishableaccount()]:
  print(item.balance())
# Out:
# 0.01
# 0.12

# %% [markdown]
# ### Q62. Override a discount method for banking case 3; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.01
class perishableaccount(Account):
    def balance(self):
      return 0.12
for item in [Account(), perishableaccount()]:
  print(item.balance())
# Out:
# 0.01
# 0.12

# %% [markdown]
# ### Q63. Use polymorphic payment processors for banking case 3; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def pay(self, account_ref, amount): ...
class Card(Payment):
    def pay(self, account_ref, amount):
        return f'Card charged {amount:.2f} for {account_ref}'
print(Card().pay('ACC-1063', 250))
# Out:
# Card charged 250.00 for ACC-1063

# %% [markdown]
# ### Q64. Compose transfer from transferline objects for banking case 3; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class TransferLine:
    def __init__(self, account, amount):
        self.account, self.amount = account, amount
    def total(self):
        return self.amount
class Transfer:
    def __init__(self, lines):
        self.lines = list(lines)
    def total(self):
        return sum(x.total() for x in self.lines)
print(Transfer([TransferLine('ACC-1064', 5000)]).total())
# Out:
# 5000

# %% [markdown]
# ### Q65. Define an abstract paymentmethod for banking case 3; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from abc import ABC,abstractmethod
class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, account_ref, amount): ...
    @abstractmethod
    def transfer(self, account_ref, amount): ...
class Card(PaymentMethod):
    def pay(self, account_ref, amount):
        return f'Card charged {amount:.2f} for {account_ref}'
    def transfer(self, account_ref, amount):
        return f'Card transferred {amount:.2f} for {account_ref}'
print(Card().pay('ACC-1065', 250))
print(Card().transfer('ACC-1065', 250))
# Out:
# Card charged 250.00 for ACC-1065
# Card transferred 250.00 for ACC-1065

# %% [markdown]
# ### Q66. Use a dataclass for inventoryrecord for banking case 3; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from dataclasses import dataclass
@dataclass
class InventoryRecord:
    account_ref: str
    item: str
    quantity: int
record = InventoryRecord('ACC-1066', 'Laptop', 10)
print(record)
# Out:
# InventoryRecord(account_ref='ACC-1066', item='Laptop', quantity=10)

# %% [markdown]
# ### Q67. Implement a custom iterator for portfolio for banking case 3; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ImplementACustomIteratorForPortfolio:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5052):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ImplementACustomIteratorForPortfolio()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5052.00 5052000.0

# %% [markdown]
# ### Q68. Use multiple inheritance carefully for timestampeditem for banking case 3; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.10
class TimestampedItem(Account):
    def balance(self):
      return 0.25
for item in [Account(), TimestampedItem()]:
  print(item.balance())
# Out:
# 0.1
# 0.25

# %% [markdown]
# ### Q69. Create a account factory for banking case 3; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class CreateAAccountFactoryForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5054):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = CreateAAccountFactoryForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5054.00 5054000.0

# %% [markdown]
# ### Q70. Apply a strategy for interest offers for banking case 3; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ApplyAStrategyForInterestOffers:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5055):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ApplyAStrategyForInterestOffers()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5055.00 5055000.0

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design an extensible pricing engine for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class DesignAnExtensiblePricingEngineForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5053):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = DesignAnExtensiblePricingEngineForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5053.00 5053000.0

# %% [markdown]
# ### Q72. Implement an observer for low balance for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ImplementAnObserverForLowBalanceForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=5051):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ImplementAnObserverForLowBalanceForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 5051.00 5051000.0

# %% [markdown]
# ### Q73. Build a state machine for transfer status for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Transfer:
    allowed = {
        'pending': {'approved', 'rejected'},
        'approved': {'completed'},
        'rejected': set(),
        'completed': set()
    }
    def __init__(self):
        self.state = 'pending'
    def move(self, new):
        if new not in self.allowed[self.state]:
            raise ValueError(f'{self.state} -> {new} not allowed')
        self.state = new
t = Transfer()
t.move('approved')
t.move('completed')
print(t.state)
# Out:
# completed

# %% [markdown]
# ### Q74. Create an immutable money value object for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from dataclasses import dataclass
@dataclass(frozen=True)
class ImmutableMoneyValueObjectForBanking:
  account:str
  amount:int
  balance:float
record=ImmutableMoneyValueObjectForBanking('ACC-1074',1000,500.0)
print(record)
# Out:
# ImmutableMoneyValueObjectForBanking(account='ACC-1074', amount=1000, balance=500.0)

# %% [markdown]
# ### Q75. Implement a unit-of-work transaction for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class UnitOfWorkTransactionForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=520):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=2000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = UnitOfWorkTransactionForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 520.00 1040000.0

# %% [markdown]
# ### Q76. Separate domain and infrastructure layers for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class SeparateDomainAndInfrastructureLayersForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = SeparateDomainAndInfrastructureLayersForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q77. Design a plugin-ready payment architecture for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class DesignAPluginReadyPaymentArchitectureForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = DesignAPluginReadyPaymentArchitectureForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q78. Implement a descriptor for positive amounts for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ImplementADescriptorForPositiveAmountsForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ImplementADescriptorForPositiveAmountsForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q79. Use cooperative inheritance with super for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.100
class TimestampedItem(Account):
    def balance(self):
      return 0.025
for item in [Account(), TimestampedItem()]:
  print(item.balance())
# Out:
# 0.1
# 0.025

# %% [markdown]
# ### Q80. Refactor a god object using solid for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class RefactorAGodObjectUsingSolidForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = RefactorAGodObjectUsingSolidForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q81. Design an extensible pricing engine for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class DesignAnExtensiblePricingEngineForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = DesignAnExtensiblePricingEngineForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q82. Implement an observer for low balance for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ImplementAnObserverForLowBalanceForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ImplementAnObserverForLowBalanceForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q83. Build a state machine for transfer status for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Transfer:
    allowed = {
        'pending': {'approved', 'rejected'},
        'approved': {'completed'},
        'rejected': set(),
        'completed': set()
    }
    def __init__(self):
        self.state = 'pending'
    def move(self, new):
        if new not in self.allowed[self.state]:
            raise ValueError(f'{self.state} -> {new} not allowed')
        self.state = new
        t = Transfer()
        t.move('approved')
        t.move('completed')
print(t.state)
# Out:
# completed

# %% [markdown]
# ### Q84. Create an immutable money value object for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from dataclasses import dataclass
@dataclass(frozen=True)
class ImmutableMoneyValueObjectForBanking:
  account:str
  amount:int
  balance:float
record=ImmutableMoneyValueObjectForBanking('ACC-1084',1000,500)
print(record)
# Out:
# ImmutableMoneyValueObjectForBanking(account='ACC-1084', amount=1000, balance=500)

# %% [markdown]
# ### Q85. Implement a unit-of-work transaction for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class UnitOfWorkTransactionForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = UnitOfWorkTransactionForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q86. Separate domain and infrastructure layers for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class SeparateDomainAndInfrastructureLayersForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = SeparateDomainAndInfrastructureLayersForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q87. Design a plugin-ready payment architecture for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class DesignAPluginReadyPaymentArchitectureForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = DesignAPluginReadyPaymentArchitectureForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q88. Implement a descriptor for positive amounts for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ImplementADescriptorForPositiveAmountsForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ImplementADescriptorForPositiveAmountsForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q89. Use cooperative inheritance with super for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.100
class TimestampedItem(Account):
    def balance(self):
      return 0.025
for item in [Account(), TimestampedItem()]:
  print(item.balance())
# Out:
# 0.1
# 0.025

# %% [markdown]
# ### Q90. Refactor a god object using solid for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class RefactorAGodObjectUsingSolidForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = RefactorAGodObjectUsingSolidForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q91. Design an extensible pricing engine for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class DesignAnExtensiblePricingEngineForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = DesignAnExtensiblePricingEngineForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q92. Implement an observer for low balance for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ImplementAnObserverForLowBalanceForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ImplementAnObserverForLowBalanceForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q93. Build a state machine for transfer status for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Transfer:
    allowed = {
        'pending': {'approved', 'rejected'},
        'approved': {'completed'},
        'rejected': set(),
        'completed': set()
    }
    def __init__(self):
        self.state = 'pending'
    def move(self, new):
        if new not in self.allowed[self.state]:
            raise ValueError(f'{self.state} -> {new} not allowed')
        self.state = new
        t = Transfer()
        t.move('approved')
        t.move('completed')
print(t.state)
# Out:
# completed

# %% [markdown]
# ### Q94. Create an immutable money value object for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from dataclasses import dataclass
@dataclass(frozen=True)
class ImmutableMoneyValueObjectForBanking:
  account:str
  amount:int
  balance:float
record=ImmutableMoneyValueObjectForBanking('ACC-1094',1000,500)
print(record)
# Out:
# ImmutableMoneyValueObjectForBanking(account='ACC-1094', amount=1000, balance=500)

# %% [markdown]
# ### Q95. Implement a unit-of-work transaction for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class UnitOfWorkTransactionForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = UnitOfWorkTransactionForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q96. Separate domain and infrastructure layers for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class SeparateDomainAndInfrastructureLayersForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = SeparateDomainAndInfrastructureLayersForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q97. Design a plugin-ready payment architecture for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class DesignAPluginReadyPaymentArchitectureForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = DesignAPluginReadyPaymentArchitectureForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q98. Implement a descriptor for positive amounts for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ImplementADescriptorForPositiveAmountsForBanking:
  bank_name = 'City Bank'
  def __init__(self, account_ref='ACC-1001', balance=500):
    self.account_ref = account_ref
    self._balance = float(balance)
  @property
  def balance(self):
    return self._balance
  def deposit(self, amount=1000):
    return self.balance*amount
  def __str__(self):
    return f'{self.account_ref} @ {self.balance:.2f}'
account = ImplementADescriptorForPositiveAmountsForBanking()
print(account, account.deposit())
# Out:
# ACC-1001 @ 500.00 500000.0

# %% [markdown]
# ### Q99. Use cooperative inheritance with super for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Account:
    def balance(self):
       return 0.100
class TimestampedItem(Account):
    def balance(self):
      return 0.025
for item in [Account(), TimestampedItem()]:
  print(item.balance())
# Out:
# 0.1
# 0.025

# %% [markdown]
# ### Q100. Refactor a god object using solid for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class RefactorAGodObjectUsingS:
    bank_name = 'City Bank'
    def __init__(self, reference='ACC-1100', amount=5000):
        self.reference = reference
        self._amount = float(amount)
    @property
    def amount(self):
        return self._amount
    def transfer_total(self, fee=100):
        return self.amount*fee
    def __str__(self):
        return f'{self.reference} @ {self.amount:.2f}'
transfer = RefactorAGodObjectUsingS()
print(transfer, transfer.transfer_total())
# Out:
# ACC-1100 @ 5000.00 500000.0
